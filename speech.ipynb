# %% [markdown]
# pip install SpeechRecognition
# pip install pyaudio
# pip install pocketsphinx

# %%
import speech_recognition as sr

# %%
rec = sr.Recognizer()
mic = sr.Microphone()

# %%
#sr.Microphone.list_microphone_names()

# %%
with mic as source:
    rec.adjust_for_ambient_noise(source, duration=0.5)
    audio = rec.listen(source)

# %% [markdown]
# recognize_bing(): Microsoft Bing Speech
# recognize_google(): Google Web Speech API
# recognize_google_cloud(): Google Cloud Speech - requires installation of the google-cloud-speech package
# recognize_houndify(): Houndify by SoundHound
# recognize_ibm(): IBM Speech to Text
# recognize_sphinx(): CMU Sphinx - requires installing PocketSphinx
# recognize_wit(): Wit.ai

# %%
rec.recognize_google(audio, language='es-ES')
# Out:
# 'estudia'

# %%
rec.recognize_sphinx(audio)
# Out:
# 'if julia'

# %% [markdown]
# [https://sourceforge.net/projects/cmusphinx/files/Acoustic%20and%20Language%20Models/](https://sourceforge.net/projects/cmusphinx/files/Acoustic%20and%20Language%20Models/)

# %%
rec.recognize_wit(audio)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 rec.recognize_wit(audio)
#
# TypeError: Recognizer.recognize_wit() missing 1 required positional argument: 'key'

# %%
print(pocketsphinx.get_model_path())
# Out:
# C:\Program Files\Python311\Lib\site-packages\pocketsphinx\model

# %%
rec.recognize_sphinx(audio, language='es-es')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 rec.recognize_sphinx(audio, language='es-es')
#
# File C:\Program Files\Python311\Lib\site-packages\speech_recognition\__init__.py:631, in Recognizer.recognize_sphinx(self, audio_data, language, keyword_entries, grammar, show_all)
#     629 config.set_string("-dict", phoneme_dictionary_file)
#     630 config.set_string("-logfn", os.devnull)  # disable logging (logging causes unwanted output in terminal)
# --> 631 decoder = pocketsphinx.Decoder(config)
#     633 # obtain audio data
#     634 raw_data = audio_data.get_raw_data(convert_rate=16000, convert_width=2)  # the included language models require audio to be 16-bit mono 16 kHz in little-endian format
#
# File _pocketsphinx.pyx:846, in _pocketsphinx.Decoder.__init__()
#
# RuntimeError: Failed to initialize PocketSphinx

# %%
texto = None
try:
    texto = rec.recognize_google(audio)
except sr.RequestError:
    print("API no disponible")
except sr.UnknownValueError:
    print("No se pudo reconocer el audio")

if texto:
    print(texto)
# Out:
# estudia

# %% [markdown]
# pip install gTTS

# %%
from gtts import gTTS
import IPython.display as ipd

# %%
tts = gTTS(text="La situación se encuentra en un nivel de abstracción superior al del contexto.", lang='es')
tts.save("audio.mp3")
ipd.Audio("audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# pip install pyttsx3

# %%
import pyttsx3

# %%
engine = pyttsx3.init()
voices = engine.getProperty('voices')
for voice in voices:
    print(voice)
# Out:
# <Voice id=HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_ES-ES_HELENA_11.0
#           name=Microsoft Helena Desktop - Spanish (Spain)
#           languages=[]
#           gender=None
#           age=None>
# <Voice id=HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0
#           name=Microsoft Zira Desktop - English (United States)
#           languages=[]
#           gender=None
#           age=None>

# %%
texto="La situación se encuentra en un nivel de abstracción superior al del contexto."
engine.setProperty('rate', 150)
engine.setProperty('voice', 'HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_ES-ES_HELENA_11.0')
#engine.say(texto);
engine.save_to_file(texto , 'audio.mp3')
engine.runAndWait()
ipd.Audio("audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
